# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Load The Dataset

# %%
df=pd.read_csv("/content/drive/MyDrive/student_performance_data.csv")

# %%
df.head()
# Out:
#    Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0              95                         86                12
# 1              78                         92                19
# 2              97                         87                23
# 3              74                         69                12
# 4              62                         74                10
#
#    Practical Score (25%)  Exam Score (50%) Performance  Age  Gender  \
# 0                     17                33           B   21  Female
# 1                     14                26           C   25    Male
# 2                     11                35           B   19    Male
# 3                      9                19           D   24    Male
# 4                     17                19           D   21  Female
#
#   Marital Status  Children (if Married) Mother Education   Father Education  \
# 0        Engaged                      0          College  Bachelor's Degree
# ...

# %% [markdown]
# #Data Preprocessing

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Attendance (%)                           5000 non-null   int64
#  1   Assignment Completion (%)                5000 non-null   int64
#  2   Test Score (25%)                         5000 non-null   int64
#  3   Practical Score (25%)                    5000 non-null   int64
#  4   Exam Score (50%)                         5000 non-null   int64
#  5   Performance                              5000 non-null   object
#  6   Age                                      5000 non-null   int64
#  7   Gender                                   5000 non-null   object
#  8   Marital Status                           5000 non-null   object
#  9   Children (if Married)                    5000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# count     5000.000000                5000.000000       5000.000000
# mean        82.863800                  82.752800         16.448200
# std         10.806341                  10.762735          5.199108
# min         21.000000                  10.000000          8.000000
# 25%         76.000000                  76.000000         12.000000
# 50%         84.000000                  84.000000         17.000000
# 75%         92.000000                  91.000000         21.000000
# max         99.000000                  99.000000         25.000000
#
#        Practical Score (25%)  Exam Score (50%)          Age  \
# count            5000.000000       5000.000000  5000.000000
# mean               16.369200         29.346000    21.476400
# std                 5.186316         12.315414     2.282649
# min                 8.000000          8.000000    18.000000
# ...

# %%
df.isnull().sum()
# Out:
# Attendance (%)                             0
# Assignment Completion (%)                  0
# Test Score (25%)                           0
# Practical Score (25%)                      0
# Exam Score (50%)                           0
# Performance                                0
# Age                                        0
# Gender                                     0
# Marital Status                             0
# Children (if Married)                      0
# Mother Education                           0
# Father Education                           0
# Guardian (Sponsor)                         0
# Extracurricular Activities                 0
# Online Time (Daily)                        0
# Family Relationship                        0
# Free Time Activities                       0
# Alcoholic Consumption                      0
# Religious Programs (Weekly)                0
# Computer/Laptop Access (for Practicals)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Attendance (%)', 'Assignment Completion (%)', 'Test Score (25%)',
#        'Practical Score (25%)', 'Exam Score (50%)', 'Performance', 'Age',
#        'Gender', 'Marital Status', 'Children (if Married)', 'Mother Education',
#        'Father Education', 'Guardian (Sponsor)', 'Extracurricular Activities',
#        'Online Time (Daily)', 'Family Relationship', 'Free Time Activities',
#        'Alcoholic Consumption', 'Religious Programs (Weekly)',
#        'Computer/Laptop Access (for Practicals)'],
#       dtype='object')

# %% [markdown]
# #Remove Un-Necessary Columns

# %%
df=df.drop(columns=[ 'Age',
       'Gender', 'Marital Status', 'Children (if Married)', 'Mother Education',
       'Father Education', 'Guardian (Sponsor)', 'Extracurricular Activities',
       'Online Time (Daily)', 'Family Relationship', 'Free Time Activities',
       'Alcoholic Consumption', 'Religious Programs (Weekly)',
       'Computer/Laptop Access (for Practicals)'])

# %%
df.head()
# Out:
#    Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0              95                         86                12
# 1              78                         92                19
# 2              97                         87                23
# 3              74                         69                12
# 4              62                         74                10
#
#    Practical Score (25%)  Exam Score (50%) Performance
# 0                     17                33           B
# 1                     14                26           C
# 2                     11                35           B
# 3                      9                19           D
# 4                     17                19           D

# %%
from pandas._libs import iNaT
# rename column
df.rename(columns={"Attendance (%)":"Attendence","Assignment Completion (%)":"Assignment","Test Score (25%)":"Test score","Practical Score (25%)":"Practical","Exam Score (50%)":"Exam score","Performance":"performance"},inplace=True)

# %%
df.head()
# Out:
#    Attendence  Assignment  Test score  Practical  Exam score performance
# 0          95          86          12         17          33           B
# 1          78          92          19         14          26           C
# 2          97          87          23         11          35           B
# 3          74          69          12          9          19           D
# 4          62          74          10         17          19           D

# %% [markdown]
#  # Checking Uniquenes of the Columns

# %%
df['Assignment'].unique()
# Out:
# array([86, 92, 87, 69, 74, 81, 77, 84, 65, 90, 83, 91, 82, 97, 80, 94, 76,
#        98, 85, 78, 63, 67, 79, 93, 62, 96, 89, 71, 75, 88, 95, 70, 66, 99,
#        27, 38, 73, 72, 60, 68, 61, 64, 26, 10, 20, 18, 31, 30, 29, 35, 24,
#        22, 15, 37])

# %%
df['Exam score'].unique()
# Out:
# array([33, 26, 35, 19, 38, 14, 16, 23, 18, 12, 46, 34, 32, 22, 43, 39, 49,
#        29, 20, 24, 36, 37,  8, 42, 21, 17, 30, 31, 48, 44, 25, 50, 40, 13,
#        27, 41,  9, 10, 28, 45, 15, 11, 47])

# %%
df['Practical'].unique()
# Out:
# array([17, 14, 11,  9, 23, 16, 21, 10, 22,  8, 13, 25, 15, 19, 12, 24, 18,
#        20])

# %%
df['Test score'].unique()
# Out:
# array([12, 19, 23, 10, 25, 22, 13, 15,  9, 18, 14, 11,  8, 20, 24, 17, 16,
#        21])

# %%
df['performance'].unique()
# Out:
# array(['B', 'C', 'D', 'A', 'E', 'F'], dtype=object)

# %%
df['Attendence'].unique()
# Out:
# array([95, 78, 97, 74, 62, 85, 83, 88, 63, 77, 92, 67, 75, 94, 96, 86, 81,
#        91, 82, 90, 79, 89, 64, 61, 84, 76, 66, 68, 98, 72, 87, 93, 71, 70,
#        80, 65, 73, 23, 22, 99, 60, 69, 32, 30, 28, 34, 33, 25, 24, 21, 27])

# %% [markdown]
# #Data Encoding

# %%
df.head(10)
# Out:
#    Attendence  Assignment  Test score  Practical  Exam score performance
# 0          95          86          12         17          33           B
# 1          78          92          19         14          26           C
# 2          97          87          23         11          35           B
# 3          74          69          12          9          19           D
# 4          62          74          10         17          19           D
# 5          85          81          25         17          38           A
# 6          83          77          22         23          14           C
# 7          85          84          13         14          35           B
# 8          62          65          15         16          16           D
# 9          88          90           9         21          23           C

# %%
# ordinal encoding library
from sklearn.preprocessing import OrdinalEncoder

# %%
performance_order=['F','E','D', 'C', 'B', 'A']
oe=OrdinalEncoder(categories=[performance_order])

# %%
df['performance']=oe.fit_transform(df[['performance']])

# %%
# Transformed dataframe
df.head()
# Out:
#    Attendence  Assignment  Test score  Practical  Exam score  performance
# 0          95          86          12         17          33          4.0
# 1          78          92          19         14          26          3.0
# 2          97          87          23         11          35          4.0
# 3          74          69          12          9          19          2.0
# 4          62          74          10         17          19          2.0

# %% [markdown]
# #Checking The Co-Relation Percentage Between Columns

# %%
plt.figure(figsize=(8,6))
plt.title("Heatmap for checking co-relation")
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: title={'center': 'Heatmap for checking co-relation'}>

# %% [markdown]
# # Train & Test Data Seperation

# %%
x=df.drop(columns=['performance'])
y=df['performance']

# %%
x
# Out:
#       Attendence  Assignment  Test score  Practical  Exam score
# 0             95          86          12         17          33
# 1             78          92          19         14          26
# 2             97          87          23         11          35
# 3             74          69          12          9          19
# 4             62          74          10         17          19
# ...          ...         ...         ...        ...         ...
# 4995          83          86          13          9          29
# 4996          88          92          17         11          31
# 4997          93          85          10         11          31
# 4998          97          77          21         22          42
# 4999          91          87          21         13          48
#
# [5000 rows x 5 columns]

# %%
y
# Out:
# 0       4.0
# 1       3.0
# 2       4.0
# 3       2.0
# 4       2.0
#        ...
# 4995    3.0
# 4996    3.0
# 4997    3.0
# 4998    5.0
# 4999    5.0
# Name: performance, Length: 5000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Data Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train= scaler.fit_transform(x_train)
x_test= scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 8.35263318e-01,  1.92075666e-01,  8.77271982e-01,
#         -7.61157843e-02,  8.58363056e-01],
#        [ 7.42448548e-01,  1.30757863e+00,  4.93093317e-01,
#          3.08064830e-01, -3.86958596e-02],
#        [ 3.71189469e-01, -4.58634394e-01,  6.85182649e-01,
#         -2.68206092e-01,  1.34766792e+00],
#        ...,
#        [-5.56958231e-01, -8.68000740e-02, -6.59442679e-01,
#          1.26851637e+00,  2.05956572e-01],
#        [-5.56958231e-01,  9.35744306e-01, -8.51532011e-01,
#          8.84335753e-01,  1.51076954e+00],
#        [-6.96110774e-05, -8.68000740e-02,  1.26145065e+00,
#         -6.52386706e-01, -8.54203965e-01]])

# %%
x_test
# Out:
# array([[-0.55695823,  1.40053721, -1.42780001, -0.07611578,  0.28750738],
#        [-0.46414346,  0.37799283,  1.45353998,  0.50015514, -0.60955153],
#        [-0.74258777,  0.37799283, -0.65944268, -1.03656732,  0.04285495],
#        ...,
#        [ 0.18555993,  1.12166147,  1.26145065, -0.84447701, -1.01730559],
#        [-0.27851392,  0.19207567,  1.26145065, -0.26820609,  1.67387116],
#        [-0.83540254, -0.83046871, -1.61988934, -1.42074794, -0.44644991]])

# %%
y_train
# Out:
# 4227    5.0
# 4676    4.0
# 800     5.0
# 3671    3.0
# 4193    5.0
#        ...
# 4426    4.0
# 466     5.0
# 3092    4.0
# 3772    5.0
# 860     3.0
# Name: performance, Length: 4000, dtype: float64

# %%
y_test
# Out:
# 1501    3.0
# 2586    4.0
# 2653    3.0
# 1055    3.0
# 705     3.0
#        ...
# 4711    5.0
# 2313    5.0
# 3214    3.0
# 2732    5.0
# 1926    2.0
# Name: performance, Length: 1000, dtype: float64

# %% [markdown]
# # Modeling & Evaluation

# %% [markdown]
# Models List
#
# 1. RandomForest Classifier
# 2. Bagging Classifier
# 3. ExtraTrees Classifier
# 4. XGB Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# %%
rfc=RandomForestClassifier()
bgc=BaggingClassifier()
etc=ExtraTreesClassifier()
xgc=XGBClassifier()

# %%
classifiers={
'RFC':rfc,
'BGC':bgc,
'ETC':etc,
'XGB':xgc
}

# %%
# Define train_classifier function with confusion matrix display and additional metrics
def train_classifier(classifier, x_train, y_train, x_test, y_test, name):
  # Train the classifier
  classifier.fit(x_train, y_train)

  # Make predictions
  y_pred = classifier.predict(x_test)

  # Calculate metrics
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred, average='weighted')
  recall = recall_score(y_test, y_pred, average='weighted')
  f1 = f1_score(y_test, y_pred, average='weighted')

  # Generate and display confusion matrix
  cm = confusion_matrix(y_test, y_pred)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)

  disp.plot(cmap=plt.cm.Blues)
  plt.title(f"Confusion Matrix for {name}")
  plt.xlabel("Predicted Labels")
  plt.ylabel("True Labels")
  plt.show()

  return accuracy, precision, recall, f1

# %%
# Lists to store accuracy, precision, recall, and F1 scores

accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []


# Loop through each classifier
for name, clf in classifiers.items():
  # Train the classifier, get metrics, and display confusion matrix
  current_accuracy, current_precision, current_recall, current_f1 = train_classifier(clf, x_train, y_train, x_test, y_test, name)


  # Print the classifier's performance metrics
  print(f'Name: {name}')
  print(f'Accuracy: {current_accuracy}')
  print(f'Precision: {current_precision}')
  print(f'Recall: {current_recall}')
  print(f'F1 Score: {current_f1}')
  print('----------------------------')

  # Append scores to the lists
  accuracy_scores.append(current_accuracy)
  precision_scores.append(current_precision)
  recall_scores.append(current_recall)
  f1_scores.append(current_f1)
# Out:
# Name: RFC
# Accuracy: 0.936
# Precision: 0.9366674045012683
# Recall: 0.936
# F1 Score: 0.9358254618141564
# ----------------------------
# Name: BGC
# Accuracy: 0.929
# Precision: 0.9300191398212261
# Recall: 0.929
# F1 Score: 0.9291442585839587
# ----------------------------
# Name: ETC
# Accuracy: 0.94
# Precision: 0.9409293085608226
# Recall: 0.94
# F1 Score: 0.9398898517133436
# ----------------------------
# Name: XGB
# Accuracy: 0.944
# Precision: 0.9446996694178121
# Recall: 0.944
# F1 Score: 0.9442572909150995
# ----------------------------

# %%
performance_df = pd.DataFrame({'Algorithm':classifiers.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores,'Recall':recall_scores,'F1 Score':f1_scores})
performance_df
# Out:
#   Algorithm  Accuracy  Precision  Recall  F1 Score
# 0       RFC     0.936   0.936667   0.936  0.935825
# 1       BGC     0.929   0.930019   0.929  0.929144
# 2       ETC     0.940   0.940929   0.940  0.939890
# 3       XGB     0.944   0.944700   0.944  0.944257

# %%
performance_df1=pd.melt(performance_df,id_vars='Algorithm')
performance_df1
# Out:
#    Algorithm   variable     value
# 0        RFC   Accuracy  0.936000
# 1        BGC   Accuracy  0.929000
# 2        ETC   Accuracy  0.940000
# 3        XGB   Accuracy  0.944000
# 4        RFC  Precision  0.936667
# 5        BGC  Precision  0.930019
# 6        ETC  Precision  0.940929
# 7        XGB  Precision  0.944700
# 8        RFC     Recall  0.936000
# 9        BGC     Recall  0.929000
# 10       ETC     Recall  0.940000
# 11       XGB     Recall  0.944000
# 12       RFC   F1 Score  0.935825
# 13       BGC   F1 Score  0.929144
# 14       ETC   F1 Score  0.939890
# 15       XGB   F1 Score  0.944257

# %%
sns.catplot(x='Algorithm',y='value',hue='variable',data=performance_df1,kind='bar',height=5)
plt.ylim(0,1)
plt.xticks(rotation='vertical')
plt.show()
